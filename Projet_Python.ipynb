# %%
import pandas as pd
import requests

# %% [markdown]
# 1) Analyse des données
#
# Nous commeçons par afficher la liste des Datasets disponnibles sur l'API de la SNCF pour identifier ceux qui nous intéressent. Nous utilisons le Catalogue qui énumère tous les Datasets afin d'obtenir le titre des 216 Datasets publics.

# %%
url_catalogue = "https://ressources.data.sncf.com/api/v2/catalog/exports/json?limit=-1&offset=0&timezone=UTC"

catalogue = requests.get(url_catalogue)
wb_cata = catalogue.json()

df_cata = pd.DataFrame(wb_cata)
df_cata.head(10)
# Out:
#                                           dataset_id  has_attachments  \
# 0                           signalisation-permanente            False
# 1                                       rapports-irc            False
# 2                    mode-de-cantonnement-des-lignes            False
# 3                       saisines-avis-mediateur-sncf            False
# 4                                    stocks-2017-cco            False
# 5                                     source-ca-2015            False
# 6  images-des-feux-de-circulation-ferroviaire-en-...            False
# 7             exposition-mediatique-report-quotidien            False
# 8                             origine-mediateur-sncf             True
# 9                                           info-ges             True
#
#    attachments_count  has_records  \
# 0                  0         True
# 1                  0         True
# 2                  0         True
# 3                  0         True
# 4                  0         True
# 5                  0         True
# 6                  0         True
# 7                  0         True
# 8                  1         True
# 9                  1        False
#
#                                               fields  \
# 0  [{'name': 'idreseau', 'label': 'IDRESEAU', 'ty...
# 1  [{'name': 'region', 'annotations': {'sortable'...
# 2  [{'name': 'code_ligne', 'annotations': {'facet...
# 3  [{'name': 'annee', 'description': None, 'annot...
# 4  [{'name': 'id', 'label': '#', 'type': 'int', '...
# 5  [{'name': 'sources_ca', 'annotations': {'facet...
# 6  [{'name': 'sequence', 'annotations': {}, 'desc...
# 7  [{'name': 'begindate', 'description': None, 'a...
# 8  [{'name': 'annee', 'description': None, 'annot...
# 9                                                 {}
#
#                                                metas              features
# 0  {'custom': {'cycle': None, 'periodicity': ['An...        [geo, analyze]
# 1  {'custom': {'cycle': None, 'periodicity': None...  [analyze, timeserie]
# 2  {'custom': {'cycle': None, 'periodicity': ['An...        [geo, analyze]
# 3  {'custom': {'cycle': None, 'periodicity': ['An...  [timeserie, analyze]
# 4  {'custom': {'cycle': None, 'periodicity': ['An...  [timeserie, analyze]
# 5  {'custom': {'cycle': None, 'periodicity': None...             [analyze]
# 6  {'custom': {'cycle': None, 'periodicity': ['Ir...  [analyze, timeserie]
# 7  {'custom': {'cycle': None, 'periodicity': ['Qu...  [analyze, timeserie]
# 8  {'custom': {'cycle': None, 'periodicity': ['An...  [timeserie, analyze]
# 9  {'custom': {'cycle': None, 'periodicity': ['An...                    []

# %% [markdown]
# On affiche certains Datasets scuceptibles de nous intéresser.

# %%
url_gares = "https://ressources.data.sncf.com/api/v2/catalog/datasets/liste-des-gares/exports/json?limit=-1&offset=0&timezone=UTC"
gares = requests.get(url_gares)
wb_gares = gares.json()

df_gares = pd.DataFrame(wb_gares)
df_gares
# Out:
#       code_uic                libelle fret voyageurs code_ligne  rg_troncon  \
# 0     87755223                 Bandol    N         O     930000           1
# 1     87696179      Pouilly-sur-Loire    O         O     750000           1
# 2     87718155                 Arbois    N         O     880000           1
# 3     87784488          Cases-de-Pène    O         N     676000           1
# 4     87481002                 Nantes    O         O     519000           1
# ...        ...                    ...  ...       ...        ...         ...
# 3814  87144055                Charmes    O         O     042000           1
# 3815  87342261          Ham-en-Artois    N         O     301000           1
# 3816  87214270              Goxwiller    N         O     111000           1
# 3817  87574251  La Chaussée-St-Victor    N         O     570000           2
# 3818  87212142             Mommenheim    N         O     070000           1
#
#            pk                   commune           departemen  idreseau  \
# 0     050+607                    BANDOL                  VAR      3077
# 1     214+004         POUILLY-SUR-LOIRE               NIEVRE      6141
# 2     401+119                    ARBOIS                 JURA      2912
# 3     463+765          ESPIRA-DE-L'AGLY  PYRENEES-ORIENTALES      3499
# 4     428+284                    NANTES     LOIRE-ATLANTIQUE      5736
# ...       ...                       ...                  ...       ...
# 3814  025+346                   CHARMES               VOSGES      3624
# 3815  246+028             HAM-EN-ARTOIS        PAS-DE-CALAIS      4404
# 3816  021+351                 GOXWILLER             BAS-RHIN      4336
# 3817  175+710  LA CHAUSSÉE-SAINT-VICTOR         LOIR-ET-CHER      4630
# 3818  479+729                MOMMENHEIM             BAS-RHIN      5547
#
#                                     idgaia         x_l93         y_l93  \
# 0     29a5a626-dfbc-11e3-a2ff-01a464e0362d  9.238337e+05  6.230702e+06
# 1     297a4c76-dfbc-11e3-a2ff-01a464e0362d  6.973583e+05  6.686913e+06
# 2     28faadb4-dfbc-11e3-a2ff-01a464e0362d  9.102539e+05  6.649514e+06
# 3     d9c2a8a8-6667-11e3-89ff-01f464e0362d  6.830511e+05  6.186628e+06
# 4     c01d1406-f312-11e3-90ff-015864e0362d  3.582595e+05  6.690441e+06
# ...                                    ...           ...           ...
# 3814  d99b0b68-6667-11e3-89ff-01f464e0362d  9.444109e+05  6.813820e+06
# 3815  2945bed4-dfbc-11e3-a2ff-01a464e0362d  6.621284e+05  7.054846e+06
# 3816  d9700bba-6667-11e3-89ff-01f464e0362d  1.031120e+06  6.824114e+06
# 3817  e029f642-19bf-11e5-82ff-01fc64e0362d  5.763866e+05  6.724932e+06
# 3818  e010c2fc-19bf-11e5-82ff-01fc64e0362d  1.041115e+06  6.860632e+06
#
#        x_wgs84    y_wgs84                                              c_geo  \
# 0     5.749816  43.140491  {'lon': 5.749815526229215, 'lat': 43.140491048...
# 1     2.965051  47.282528  {'lon': 2.965051211539136, 'lat': 47.282528482...
# 2     5.763090  46.912701  {'lon': 5.763090017438219, 'lat': 46.912701321...
# 3     2.793117  42.778983  {'lon': 2.793116620024166, 'lat': 42.778983389...
# 4    -1.518766  47.226239  {'lon': -1.518765979566461, 'lat': 47.22623886...
# ...        ...        ...                                                ...
# 3814  6.301733  48.378685  {'lon': 6.301733373092041, 'lat': 48.378685295...
# 3815  2.466076  50.589560  {'lon': 2.466075551732472, 'lat': 50.589559825...
# 3816  7.478786  48.432772  {'lon': 7.478786397235771, 'lat': 48.432772201...
# 3817  1.354420  47.613178  {'lon': 1.3544202800267977, 'lat': 47.61317849...
# 3818  7.642683  48.755516  {'lon': 7.642682831064142, 'lat': 48.755516426...
#
#                                            geo_point_2d  \
# 0     {'lon': 5.749815526229215, 'lat': 43.140491047...
# 1     {'lon': 2.965051211539134, 'lat': 47.282528481...
# 2     {'lon': 5.763090017438219, 'lat': 46.912701320...
# 3     {'lon': 2.7931166200241657, 'lat': 42.77898338...
# 4     {'lon': -1.5187659795664639, 'lat': 47.2262388...
# ...                                                 ...
# 3814  {'lon': 6.301733373092041, 'lat': 48.378685294...
# 3815  {'lon': 2.466075551732471, 'lat': 50.589559825...
# 3816  {'lon': 7.478786397235773, 'lat': 48.432772201...
# 3817  {'lon': 1.3544202800267964, 'lat': 47.61317849...
# 3818  {'lon': 7.642682831064143, 'lat': 48.755516425...
#
#                                               geo_shape
# 0     {'type': 'Feature', 'geometry': {'coordinates'...
# 1     {'type': 'Feature', 'geometry': {'coordinates'...
# 2     {'type': 'Feature', 'geometry': {'coordinates'...
# 3     {'type': 'Feature', 'geometry': {'coordinates'...
# 4     {'type': 'Feature', 'geometry': {'coordinates'...
# ...                                                 ...
# 3814  {'type': 'Feature', 'geometry': {'coordinates'...
# 3815  {'type': 'Feature', 'geometry': {'coordinates'...
# 3816  {'type': 'Feature', 'geometry': {'coordinates'...
# 3817  {'type': 'Feature', 'geometry': {'coordinates'...
# 3818  {'type': 'Feature', 'geometry': {'coordinates'...
#
# [3819 rows x 18 columns]
